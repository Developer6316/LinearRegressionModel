# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
#Loading the data
df = pd.read_csv("salesdata.csv", skiprows=1, names=['tv', 'radio', 'newspaper', 'sales'])
print(df.head())
# Out:
#       tv  radio  newspaper  sales
# 0   44.5   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
features =  df.loc[:, 'tv':'newspaper']
output = df['sales']

# %%
x_train,x_test,y_train,y_test = train_test_split(features,output,test_size=0.1,random_state=3)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
print("R2 Score:", r2_score(y_test, y_pred))
print("The actual sales value for the test set is:", y_test)
print("The coefficients are:", model.coef_)
print("The intercept is:", model.intercept_)
# Out:
# R2 Score: 0.8102342512848845
# The actual sales value for the test set is: 189    13.6
# 183    23.4
# 118    22.8
# 165    16.9
# 160    16.3
# 70     19.5
# 173    10.8
# 154    16.9
# 25     21.4
# 71     10.9
# 77     10.8
# 146    12.0
# 121    17.8
# 102    10.9
# 47     13.0
# 188    23.5
# 156    19.8
# 38     18.2
# 162    18.6
# 141    20.1
# 202    20.4
# Name: sales, dtype: float64
# The coefficients are: [0.04453142 0.17465882 0.01742904]
# The intercept is: 3.4590869099570885

# %%
#model.predict([[100,100,100]])
# Out:
# /usr/lib/python3/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([27.12101505])
